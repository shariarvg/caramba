# %%
# !pip3 install convokit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 74.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 59.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 14.7 MB/s eta 0:00:00
# ...

# %%
from convokit import Corpus, download
# Out:
# An error occurred: All ufuncs must have type `numpy.ufunc`. Received (<ufunc 'sph_legendre_p'>, <ufunc 'sph_legendre_p'>, <ufunc 'sph_legendre_p'>)
# /usr/local/lib/python3.11/dist-packages/convokit/__init__.py:26: UserWarning: If you are using ConvoKit with Google Colab, incorrect versions of some packages (ex. scipy) may be imported while runtime start. To fix the issue, restart the session and run all codes again. Thank you!
#   warnings.warn(

# %%
corpus = Corpus(filename=download("movie-corpus"))
# Out:
# No configuration file found at /root/.convokit/config.yml; writing with contents:
# # Default Backend Parameters
# db_host: localhost:27017
# data_directory: ~/.convokit/saved-corpora
# model_directory: ~/.convokit/saved-models
# default_backend: mem
# ...

# %%
df = corpus.get_conversations_dataframe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9970a8dc9e6f> in <cell line: 0>()
# ----> 1 df = corpus.get_conversations_dataframe()
#
# /usr/local/lib/python3.11/dist-packages/convokit/model/corpus.py in get_conversations_dataframe(self, selector, exclude_meta)
#     489         :return: a pandas DataFrame
#     490         """
# --> 491         return get_conversations_dataframe(self, selector, exclude_meta)
#     492
#     493     def iter_speakers(
#
# /usr/local/lib/python3.11/dist-packages/convokit/model/corpusUtil.py in get_conversations_dataframe(obj, selector, exclude_meta)
#      56         ds[convo.id] = d
#      57
# ---> 58     df = pd.DataFrame(ds).T
#      59     return df.set_index("id")
#      60
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
# ...

# %%
utterance_ids = corpus.utterances.keys()

# %%
convo_keys = corpus.conversations.keys()

# %%
convo1 = list(convo_keys)[3]

# %%
corpus.

# %%
utterances_convo1 = [corpus.utterances[u].text for u in utterance_ids if corpus.utterances[u].conversation_id == convo1]

# %%
utterances_convo1
# Out:
# ["Okay -- you're gonna need to learn how to lie.",
#  'No',
#  'I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?']

# %%
def inorno(u):
  return corpus.utterances[u].speaker.meta.__getitem__('movie_name')=='10 things i hate about you'

utterance_in = [corpus.utterances[u].text for u in utterance_ids if inorno(u)]

# %%
utterance_in
# Out:
# ['They do not!',
#  'They do to!',
#  'I hope so.',
#  'She okay?',
#  "Let's go.",
#  'Wow',
#  "Okay -- you're gonna need to learn how to lie.",
#  'No',
#  'I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?',
#  'Like my fear of wearing pastels?',
#  'The "real you".',
#  'What good stuff?',
#  "I figured you'd get to the good stuff eventually.",
#  'Thank God!  If I had to hear one more story about your coiffure...',
#  "Me.  This endless ...blonde babble. I'm like, boring myself.",
#  'What crap?',
#  'do you listen to this crap?',
#  'No...',
#  'Then Guillermo says, "If you go any lighter, you\'re gonna look like an extra on 90210."',
#  'You always been this selfish?',
#  'But',
#  "Then that's all you had to say.",
#  'Well, no...',
#  "You never wanted to go out with 'me, did you?",
#  'I was?',
#  'I looked for you back at the party, but you always seemed to be "occupied".',
#  'Tons',
#  'Have fun tonight?',
# ...
